# %%
import json
from argparse import ArgumentParser
import requests
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure
from bson import json_util, ObjectId

# %%
client = MongoClient('mongodb://localhost:27017')
try:
    client.admin.command('ismaster')
    print('MongoDB connection: Success')
except ConnectionFailure as cf:
    print('MongoDB connection: failed', cf)
DBS = ['libros']
# Out:
# MongoDB connection: Success

# %%
client2 = MongoClient('mongodb+srv://esfot:esfot@cluster0.gpdvt.mongodb.net/libros?retryWrites=true&w=majority')
try:
    client2.admin.command('ismaster')
    print('MongoDB connection: Success')
except ConnectionFailure as cf:
    print('MongoDB connection: failed', cf)

DBS = client2.get_database('LIBROS')
db2 = DBS.drama
# Out:
# MongoDB connection: Success

# %%
for db in DBS:
    if db not in ('admin', 'local','config'):  
        cols = client[db].list_collection_names()  
        for col in cols:
            print('Querying documents from collection {} in database {}'.format(col, db))
            for x in client[db][col].find():  
                try:
                    documents=json.loads(json_util.dumps(x))
                    documents["_id"]=str(documents["_id"]['$oid'])
                    print(documents)
                    #doc=dbc.save(documents)
                    db2.insert_one(documents)
                except TypeError as t:

                    print('current document raised error: {}'.format(t))
                    SKIPPED.append(x)  # creating list of skipped documents for later analysis
                    continue    # continue to next document
                except Exception as e:
                    raise e
# Out:
# Querying documents from collection drama in database libros
# {'_id': '5fefa9628d3a5f2fc8a29131', 'total': 308, 'result': [{'categories': [], 'created_at': '2020-01-05 13:42:18.823766', 'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png', 'id': 'mSRa1SQRRwiIoN2JmnMV2g', 'updated_at': '2020-01-05 13:42:18.823766', 'url': 'https://api.chucknorris.io/jokes/mSRa1SQRRwiIoN2JmnMV2g', 'value': 'Chuck Norris won the daytona 500 in a flintstone car'}, {'categories': [], 'created_at': '2020-01-05 13:42:18.823766', 'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png', 'id': 'VvGL-lRHSsOL-jj9IEDWRA', 'updated_at': '2020-01-05 13:42:18.823766', 'url': 'https://api.chucknorris.io/jokes/VvGL-lRHSsOL-jj9IEDWRA', 'value': "Chuck Norris doesn't beat people up he looks at them they get scared and fight their self to the death"}, {'categories': [], 'created_at': '2020-01-05 13:42:18.823766', 'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png', 'id': 'WIWNL3WPTpGEfQXz896NhQ', 'updated_at': '2020-01-05 13:42:18.823766', 'url': 'https://api.chucknorris.io/jokes/WIWNL3WPTpGEfQXz896NhQ', 'value': 'Chuck Norris scares leftovers into being fresh with one bite'}, {'categories': [], 'created_at': '2020-01-05 13:42:18.823766', 'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png', 'id': 'MlP1e4owRr-PyO9kIqlAfg', 'updated_at': '2020-01-05 13:42:18.823766', 'url': 'https://api.chucknorris.io/jokes/MlP1e4owRr-PyO9kIqlAfg', 'value': 'Chuck Norris stopped at a stop sign, it turned green. Someone once asked Chuck Norris for advice, he\'s know dead. Chuck Norris saw a man tell his gf "you take my breathe away" he kicked him in the chest and said "wrong" Even Chuck Norris shadows is scared of him. Someone thought prank calling Chuck Norris from across the world would keep him save, he kicked him through the phone. When Ch
# ---------------------------------------------------------------------------
# DuplicateKeyError                         Traceback (most recent call last)
# <ipython-input-10-4a47ae39b05d> in <module>
#      17                     continue    # continue to next document
#      18                 except Exception as e:
# ---> 19                     raise e
#
# <ipython-input-10-4a47ae39b05d> in <module>
#      10                     print(documents)
#      11                     #doc=dbc.save(documents)
# ---> 12                     db2.insert_one(documents)
#      13                 except TypeError as t:
#      14
#
# c:\python\python382\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session)
#     696         write_concern = self._write_concern_for(session)
#     697         return InsertOneResult(
# --> 698             self._insert(document,
#     699                          write_concern=write_concern,
#     700                          bypass_doc_val=bypass_document_validation,
#
# c:\python\python382\lib\site-packages\pymongo\collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     611         """Internal insert helper."""
#     612         if isinstance(docs, abc.Mapping):
# --> 613             return self._insert_one(
#     614                 docs, ordered, check_keys, manipulate, write_concern, op_id,
#     615                 bypass_doc_val, session)
#
# c:\python\python382\lib\site-packages\pymongo\collection.py in _insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     600             _check_write_command_response(result)
#     601
# --> 602         self.__database.client._retryable_write(
#     603             acknowledged, _insert_command, session)
#     604
#
# c:\python\python382\lib\site-packages\pymongo\mongo_client.py in _retryable_write(self, retryable, func, session)
#    1496         """Internal retryable write helper."""
#    1497         with self._tmp_session(session) as s:
# -> 1498             return self._retry_with_session(retryable, func, s, None)
#    1499
#    1500     def _handle_getlasterror(self, address, error_msg):
#
# c:\python\python382\lib\site-packages\pymongo\mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1382         retryable = (retryable and self.retry_writes
#    1383                      and session and not session.in_transaction)
# -> 1384         return self._retry_internal(retryable, func, session, bulk)
#    1385
#    1386     def _retry_internal(self, retryable, func, session, bulk):
#
# c:\python\python382\lib\site-packages\pymongo\mongo_client.py in _retry_internal(self, retryable, func, session, bulk)
#    1414                             raise last_error
#    1415                         retryable = False
# -> 1416                     return func(session, sock_info, retryable)
#    1417             except ServerSelectionTimeoutError:
#    1418                 if is_retrying():
#
# c:\python\python382\lib\site-packages\pymongo\collection.py in _insert_command(session, sock_info, retryable_write)
#     598                 retryable_write=retryable_write)
#     599
# --> 600             _check_write_command_response(result)
#     601
#     602         self.__database.client._retryable_write(
#
# c:\python\python382\lib\site-packages\pymongo\helpers.py in _check_write_command_response(result)
#     220     write_errors = result.get("writeErrors")
#     221     if write_errors:
# --> 222         _raise_last_write_error(write_errors)
#     223
#     224     error = result.get("writeConcernError")
#
# c:\python\python382\lib\site-packages\pymongo\helpers.py in _raise_last_write_error(write_errors)
#     201     error = write_errors[-1]
#     202     if error.get("code") == 11000:
# --> 203         raise DuplicateKeyError(error.get("errmsg"), 11000, error)
#     204     raise WriteError(error.get("errmsg"), error.get("code"), error)
#     205
#
# DuplicateKeyError: E11000 duplicate key error collection: LIBROS.drama index: _id_ dup key: { _id: "5fefa9628d3a5f2fc8a29131" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'_id': 1}, 'keyValue': {'_id': '5fefa9628d3a5f2fc8a29131'}, 'errmsg': 'E11000 duplicate key error collection: LIBROS.drama index: _id_ dup key: { _id: "5fefa9628d3a5f2fc8a29131" }'}
